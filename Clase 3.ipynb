# %% [markdown]
# <a href="https://colab.research.google.com/github/arielbotti/CoderHouse/blob/main/Clase%203.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=13
print(x==6)
# Out:
# False
